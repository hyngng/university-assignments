# %% [markdown]
# - 2026-03-27 수업 중 실습. `titanic.csv` 데이터에 대해 `Survived` 예측하기
# - 데이터 정제 없음
#
# |API 모델|결과값|
# |---|---|
# |logistic regression|0.7892376681614349|
# |decision tree|0.7533632286995515|
# |random forest|0.8340807174887892|

# %%
# 공통부
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
import pandas as pd

path = '../../data/titanic.csv'
df = pd.read_csv(path, index_col=0)

y=df['Survived']
y.value_counts()

X=df.drop('Survived',axis=1)
X.head()

# 낚이기 전 접근법 => 옳은 접근이었음.
# X=X.drop(columns=['Name', 'Sex', 'Ticket', 'Fare', 'Cabin', 'Embarked'], errors='ignore')
# X = X.fillna(X.median(numeric_only=True))

print("열과 결측치 개수 묶어서 모두 출력:")
print(df.isnull().sum()) #  0, 0, 0, 0, 177, 0, ...

df['Age'] = df['Age'].fillna(df['Age'].median())
df['Fare'] = df['Fare'].fillna(df['Fare'].median())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

le = LabelEncoder()
df['Name'] = le.fit_transform(df['Name'])
df['Sex'] = le.fit_transform(df['Sex'])
df['Ticket'] = le.fit_transform(df['Ticket'])
df['Cabin'] = le.fit_transform(df['Cabin'])
df['Embarked'] = le.fit_transform(df['Embarked'])

y = df['Survived']
X = df.drop('Survived', axis=1)
# Out:
# 열과 결측치 개수 묶어서 모두 출력:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# # **logistic regression**

# %%
from sklearn.linear_model import LogisticRegression

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

clf_lr = LogisticRegression(random_state=0, max_iter=1000)
clf_lr.fit(X_train, y_train)

pred_lr = clf_lr.predict(X_test)

print ("\n--- Logistic Regression Classifier ---")
print (accuracy_score(y_test, pred_lr))
print (confusion_matrix(y_test, pred_lr))
# Out:
# --- Logistic Regression Classifier ---
# 0.7892376681614349
# [[114  25]
#  [ 22  62]]
# c:\Users\kiw60\Desktop\intro-to-ai\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# # **decision tree**

# %%
from sklearn.tree import DecisionTreeClassifier

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

clf_dt = DecisionTreeClassifier(random_state=0)
clf_dt.fit(X_train, y_train)

pred_dt = clf_dt.predict(X_test)

print ("\n--- Decision Tree Classifier ---")
print (accuracy_score(y_test, pred_dt))
print (confusion_matrix(y_test, pred_dt))
# Out:
# --- Decision Tree Classifier ---
# 0.7533632286995515
# [[108  31]
#  [ 24  60]]

# %% [markdown]
# # **random forest**

# %%
from sklearn.ensemble import RandomForestClassifier

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

clf_rf = RandomForestClassifier(random_state=0)
clf_rf.fit(X_train, y_train)

pred_rf = clf_rf.predict(X_test)

print ("\n--- Random Forest Classifier ---")
print (accuracy_score(y_test, pred_rf))
print (confusion_matrix(y_test, pred_rf))
# Out:
# --- Random Forest Classifier ---
# 0.8340807174887892
# [[125  14]
#  [ 23  61]]
