# %% [markdown]
# # **linear-regression**

# %%
import pandas as pd
import numpy as np

path = '../../data/breast_cancer.csv'

# breast_cancer.csv는 0번째 열이 0, 1, 2...로 무의미함
# index_col=0 => 정확도를 높이기 위해 추가한 파라미터
df  = pd.read_csv(path, index_col=0)

df2 = df.drop('label',axis=1)
df.head()

y = df2['worst compactness']
y.value_counts()

X = df2.drop('worst compactness',axis=1)
X.head()

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state=0)

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

model = LinearRegression()
model.fit(X_train, y_train)

ly_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(ly_preds, y_test))

def mse_np(actual, predicted):
    return np.mean((np.array(actual) - np.array(predicted)) ** 2)

print('평균제곱근오차', mse_np(ly_preds, y_test))

def mse(actual, predicted):
    sum_square_error = sum((a - p) ** 2 for a, p in zip(actual, predicted))
    mean_square_error = sum_square_error / len(actual)
    return mean_square_error

print('평균제곱근오차', mse(ly_preds, y_test))
# Out:
# 평균제곱근오차 0.0004971870077830557
# 평균제곱근오차 0.0004971870077830557
# 평균제곱근오차 0.0004971870077830556

# %% [markdown]
# # **decision-tree**

# %%
import pandas as pd
import numpy as np

path = '../../data/breast_cancer.csv'

df  = pd.read_csv(path)

df2 = df.drop('label',axis=1)
df.head()

y = df2['worst compactness']
y.value_counts()

X = df2.drop('worst compactness',axis=1)
X.head()

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state=0)

from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

model = DecisionTreeRegressor()
model.fit(X_train, y_train)

dy_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(dy_preds, y_test))

def mse_np(actual, predicted):
    return np.mean((np.array(actual) - np.array(predicted)) ** 2)

print('평균제곱근오차', mse_np(dy_preds, y_test))

def mse(actual, predicted):
    sum_square_error = sum((a - p) ** 2 for a, p in zip(actual, predicted))
    mean_square_error = sum_square_error / len(actual)
    return mean_square_error

print('평균제곱근오차', mse(dy_preds, y_test))
# Out:
# 평균제곱근오차 0.007885367494405594
# 평균제곱근오차 0.007885367494405594
# 평균제곱근오차 0.007885367494405594

# %% [markdown]
# # **random-forest**

# %%
import pandas as pd
import numpy as np

path = '../../data/breast_cancer.csv'

df  = pd.read_csv(path)

df2 = df.drop('label',axis=1)
df.head()

y = df2['worst compactness']
y.value_counts()

X = df2.drop('worst compactness',axis=1)
X.head()

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state=0)

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

model = RandomForestRegressor()
model.fit(X_train, y_train)

ry_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(ry_preds, y_test))

def mse_np(actual, predicted):
    return np.mean((np.array(actual) - np.array(predicted)) ** 2)

print('평균제곱근오차', mse_np(ry_preds, y_test))

def mse(actual, predicted):
    sum_square_error = sum((a - p) ** 2 for a, p in zip(actual, predicted))
    mean_square_error = sum_square_error / len(actual)
    return mean_square_error

print('평균제곱근오차', mse(ry_preds, y_test))
# Out:
# 평균제곱근오차 0.0025451383749390895
# 평균제곱근오차 0.0025451383749390895
# 평균제곱근오차 0.0025451383749390878
