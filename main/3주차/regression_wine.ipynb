# %% [markdown]
# - 2026-03-20 수업 중 실습
# - regression => Wine은 지우고, alcohol로. (Wine을 예측)

# %%
import pandas as pd
import numpy as np

path = '../../../data/wine.csv'

df = pd.read_csv(path)

df2 = df.drop('Wine', axis=1)

y = df2['Alcohol']

X = df2.drop('Alcohol', axis=1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # **linear-regression**

# %%
from sklearn.linear_model import LinearRegression

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

model = LinearRegression()
model.fit(X_train, y_train)

ly_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(ly_preds, y_test))

def mse_np(actual, predicted):
    return np.mean((np.array(actual) - np.array(predicted)) ** 2)

print('평균제곱근오차', mse_np(ly_preds, y_test))

def mse(actual, predicted):
    sum_square_error = sum((a - p) ** 2 for a, p in zip(actual, predicted))
    mean_square_error = sum_square_error / len(actual)
    return mean_square_error

print('평균제곱근오차', mse(ly_preds, y_test))
# Out:
# 평균제곱근오차 0.40168520230072413
# 평균제곱근오차 0.40168520230072413
# 평균제곱근오차 0.40168520230072413

# %% [markdown]
# # **decision-tree**

# %%
from sklearn.tree import DecisionTreeRegressor

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

model = DecisionTreeRegressor()
model.fit(X_train, y_train)

dy_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(dy_preds, y_test))

def mse_np(actual, predicted):
    return np.mean((np.array(actual) - np.array(predicted)) ** 2)

print('평균제곱근오차', mse_np(dy_preds, y_test))

def mse(actual, predicted):
    sum_square_error = sum((a - p) ** 2 for a, p in zip(actual, predicted))
    mean_square_error = sum_square_error / len(actual)
    return mean_square_error

print('평균제곱근오차', mse(dy_preds, y_test))
# Out:
# 평균제곱근오차 0.6357333333333334
# 평균제곱근오차 0.6357333333333334
# 평균제곱근오차 0.6357333333333334

# %% [markdown]
# # **random-forest**

# %%
from sklearn.ensemble import RandomForestRegressor

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

model = RandomForestRegressor()
model.fit(X_train, y_train)

ry_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(ry_preds, y_test))

def mse_np(actual, predicted):
    return np.mean((np.array(actual) - np.array(predicted)) ** 2)

print('평균제곱근오차', mse_np(ry_preds, y_test))

def mse(actual, predicted):
    sum_square_error = sum((a - p) ** 2 for a, p in zip(actual, predicted))
    mean_square_error = sum_square_error / len(actual)
    return mean_square_error

print('평균제곱근오차', mse(ry_preds, y_test))
# Out:
# 평균제곱근오차 0.4705227911111099
# 평균제곱근오차 0.4705227911111099
# 평균제곱근오차 0.47052279111110973

# %% [markdown]
# # **KNN**

# %%
from sklearn.neighbors import KNeighborsRegressor

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

knn = KNeighborsRegressor(n_neighbors=5)

knn.fit(X_train, y_train)

pred = knn.predict(X_test)
print('평균제곱근오차', mean_squared_error(pred, y_test))

def mse_np(actual, predicted):
    return np.mean((np.array(actual) - np.array(predicted)) ** 2)

print('평균제곱근오차', mse_np(pred, y_test))

def mse(actual, predicted):
    sum_square_error = sum((a - p) ** 2 for a, p in zip(actual, predicted))
    mean_square_error = sum_square_error / len(actual)
    return mean_square_error

print('평균제곱근오차', mse(pred, y_test))
# Out:
# 평균제곱근오차 0.34925911111111185
# 평균제곱근오차 0.34925911111111185
# 평균제곱근오차 0.3492591111111118
